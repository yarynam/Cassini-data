# %%
##### Major moons and Cassini positions during Grand Finale

# %%
# Import matplotlib for visualization
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# import json lib to get nice ad valid json 
import json 
from datetime import datetime

import spiceypy as spice

#check if spiceypy is loaded
spice.tkvrsn("TOOLKIT")
# Out:
# 'CSPICE_N0066'

# %%
# load all text files and kernels
spice.furnsh("./cassMetaK.txt")

# %%
# number of positions
step = 20000 

# we are going to get positions between these two dates
utc = ['2017-04-23T03:46:00', '2017-09-15T10:45:00']

# get et values, we could vectorize str2et
etOne = spice.str2et(utc[0])
etTwo = spice.str2et(utc[1])

print("ET One: {}, ET Two: {}".format(etOne, etTwo))
# Out:
# ET One: 546191226.186, ET Two: 558744366.182

# %%
# get times
times = [x*(etTwo-etOne)/step + etOne for x in range(step)]

# get utc times
times_utc = map(lambda t : spice.timout(t, "YYYY-MM-DD HR:MN:SC", 20), times)

# %%
#Cassini + moons

grandFinale = [{"name": "MIMAS"},
           {"name": "ENCELADUS"},
           {"name": "TETHYS"},
           {"name": "DIONE"},
           {"name": "RHEA"},
           {"name": "TITAN"},
           {"name": "IAPETUS"},
           {"name": "Cassini"}]

# %%
for body in grandFinale:
    positions, lightTimes = spice.spkpos(body["name"], times, 'J2000', 'NONE', 'SATURN')

    grandFinalePos = []
    for i, old_dict in enumerate(positions):
        new_dict = {"x":round(old_dict[1]/1000, 5), 
                    "y":round(old_dict[2]/1000, 5),
                    "z":round(old_dict[0]/1000, 5),
                    "t": times_utc[i] #time
                   }
        grandFinalePos.append(new_dict)
    
    body["GFpositions"] = grandFinalePos
  


# print first position
print(grandFinale[0]) 

# write json
with open("grand_finale_all.json", "w") as f:
    f.write("%s" % json.dumps(grandFinale))
# Out:
# {'name': 'MIMAS', 'GFpositions': [{'y': 25.53674, 'x': -114.27866, 'z': -144.1901, 't': '2017-04-23 03:46:00'}, {'y': 25.47396, 'x': -121.28847, 'z': -138.59257, 't': '2017-04-23 03:56:27'}, {'y': 25.35176, 'x': -128.01561, 'z': -132.67202, 't': '2017-04-23 04:06:55'}, {'y': 25.17058, 'x': -134.44525, 'z': -126.44314, 't': '2017-04-23 04:17:22'}, {'y': 24.93102, 'x': -140.56332, 'z': -119.92121, 't': '2017-04-23 04:27:50'}, {'y': 24.63379, 'x': -146.35652, 'z': -113.12211, 't': '2017-04-23 04:38:18'}, {'y': 24.27972, 'x': -151.81239, 'z': -106.06227, 't': '2017-04-23 04:48:45'}, {'y': 23.8698, 'x': -156.91928, 'z': -98.75861, 't': '2017-04-23 04:59:13'}, {'y': 23.4051, 'x': -161.6664, 'z': -91.22852, 't': '2017-04-23 05:09:41'}, {'y': 22.88684, 'x': -166.0438, 'z': -83.48979, 't': '2017-04-23 05:20:08'}, {'y': 22.31632, 'x': -170.04242, 'z': -75.5606, 't': '2017-04-23 05:30:36'}, {'y': 21.69498, 'x': -173.65409, 'z': -67.45947, 't': '2017-04-23 05:41:04'}, {'y': 21.02436, 'x': -176.87152, 'z': -59.20518, 't': '2017-04-23 05:51:31'}, {'y': 20.30608, 'x': -179.68835, 'z': -50.81678, 't': '2017-04-23 06:01:59'}, {'y': 19.54187, 'x': -182.09908, 'z': -42.31352, 't': '2017-04-23 06:12:27'}, {'y': 18.73356, 'x': -184.09913, 'z': -33.71483, 't': '2017-04-23 06:22:54'}, {'y': 17.88306, 'x': -185.68483, 'z': -25.04026, 't': '2017-04-23 06:33:22'}, {'y': 16.99237, 'x': -186.85341, 'z': -16.30943, 't': '2017-04-23 06:43:50'}, {'y': 16.06356, 'x': -187.60302, 'z': -7.54203, 't': '2017-04-23 06:54:17'}, {'y': 15.09877, 'x': -187.93269, 'z': 1.24226, 't': '2017-04-23 07:04:45'}, {'y': 14.10022, 'x': -187.84239, 'z': 10.02377, 't': '2017-04-23 07:15:13'}, {'y': 13.07019, 'x': -187.33294, 'z': 18.78291, 't': '2017-04-23 07:25:40'}, {'y': 12.01103, 'x': -186.40606, 'z': 27.50021, 't': '2017-04-23 07:36:08'}, {'y': 10.92514, 'x': -185.06436, 'z': 36.15632, 't': '2017-04-23 07:46:36'}, {'y': 9.81495, 'x': -183.3113, 'z': 44.73206, 't': '2017-04-23 07:57:03'}, {'y': 8.68297, 'x': -181.1512, 'z': 53.20848, 't': '2017-04-23 08:07:31'}, {'y': 7.53173, 'x': -178.58923, 'z': 61.56686, 't': '2017-04-23 08:17:59'}, {'y': 6.3638, 'x': -175.63139, 'z': 69.78877, 't': '2017-04-23 08:28:26'}, {'y': 5.18177, 'x': -172.2845, 'z': 77.8561, 't': '2017-04-23 08:38:54'}, {'y': 3.98828, 'x': -168.55618, 'z': 85.75105, 't': '2017-04-23 08:49:22'}, {'y': 2.78598, 'x': -164.45484, 'z': 93.45624, 't': '2017-04-23 08:59:49'}, {'y': 1.57753, 'x': -159.98966, 'z': 100.95467, 't': '2017-04-23 09:10:17'}, {'y': 0.3656, 'x': -155.17058, 'z': 108.22979, 't': '2017-04-23 09:20:45'}, {'y': -0.84711, 'x': -150.00827, 'z': 115.26551, 't': '2017-04-23 09:31:12'}, {'y': -2.05793, 'x': -144.51411, 'z': 122.04625, 't': '2017-04-23 09:41:40'}, {'y': -3.26417, 'x': -138.70019, 'z': 128.55693, 't': '2017-04-23 09:52:07'}, {'y': -4.46316, 'x': -132.57926, 'z': 134.78306, 't': '2017-04-23 10:02:35'}, {'y': -5.65224, 'x': -126.16472, 'z': 140.71071, 't': '2017-04-23 10:13:03'}, {'y': -6.82876, 'x': -119.47061, 'z': 146.32655, 't': '2017-04-23 10:23:30'}, {'y': -7.9901, 'x': -112.51156, 'z': 151.6179, 't': '2017-04-23 10:33:58'}, {'y': -9.13367, 'x': -105.3028, 'z': 156.57274, 't': '2017-04-23 10:44:26'}, {'y': -10.25691, 'x': -97.86008, 'z': 161.17972, 't': '2017-04-23 10:54:53'}, {'y': -11.3573, 'x': -90.19971, 'z': 165.42821, 't': '2017-04-23 11:05:21'}, {'y': -12.43236, 'x': -82.33848, 'z': 169.30831, 't': '2017-04-23 11:15:49'}, {'y': -13.47964, 'x': -74.29364, 'z': 172.81087, 't': '2017-04-23 11:26:16'}, {'y': -14.49678, 'x': -66.08288, 'z': 175.92752, 't': '2017-04-23 11:36:44'}, {'y': -15.48144, 'x': -57.72433, 'z': 178.65067, 't': '2017-04-23 11:47:12'}, {'y': -16.43137, 'x': -49.23645, 'z': 180.97356, 't': '2017-04-23 11:57:39'}, {'y': -17.34437, 'x': -40.63806, 'z': 182.89027, 't': '2017-04-23 12:08:07'}, {'y': -18.21832, 'x': -31.94829, 'z': 184.39572, 't': '2017-04-23 12:18:35'}, {'y': -19.05116, 'x': -23.18654, 'z': 185.48569, 't': '2017-04-23 12:29:02'}, {'y': -19.84093, 'x' ...
